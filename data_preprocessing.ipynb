# %%
import pandas as pd
import numpy as np

# %%
train_data = pd.read_excel('/content/drive/MyDrive/toy_project/data/train.xlsx')
val_data = pd.read_excel('/content/drive/MyDrive/toy_project/data/val.xlsx')

# %%
train_data.to_csv(r'/content/drive/MyDrive/toy_project/data/train.csv',index=False)
val_data.to_csv(r'/content/drive/MyDrive/toy_project/data/val.csv', index = False)

# %%
train = pd.read_csv('/content/drive/MyDrive/toy_project/data/train.csv')
val = pd.read_csv('/content/drive/MyDrive/toy_project/data/val.csv')

# %%
train = train[['감정_대분류','사람문장1']]
val = val[['감정_대분류','사람문장1']]

# %%
train.value_counts('감정_대분류')
# Out:
# 감정_대분류
# 불안    9320
# 분노    9160
# 상처    9143
# 슬픔    9125
# 당황    8756
# 기쁨    6126
# dtype: int64

# %%
val.value_counts('감정_대분류')
# Out:
# 감정_대분류
# 분노    1257
# 기쁨    1213
# 불안    1113
# 당황    1048
# 상처    1007
# 슬픔    1003
# dtype: int64

# %%
train.to_csv(r'/content/drive/MyDrive/toy_project/data/train_1.csv')
val.to_csv(r'/content/drive/MyDrive/toy_project/data/val_1.csv')
